# %%
import cv2

# %%
cap = cv2.VideoCapture('test_save.mp4')
length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
fps = cap.get(cv2.CAP_PROP_FPS)
size = (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))

# %%
# Define the codec and create VideoWriter object.The output is stored in 'outpy.avi' file.
# Define the fps to be equal to 10. Also frame size is passed.
#out = cv2.VideoWriter('output.avi',cv2.VideoWriter_fourcc('M','J','P','G'), fps, size)

fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output.mp4', fourcc, fps, size)

# %%
frame_number=0    
while cap.isOpened():
    frame_number+=1
    ret, frame = cap.read()
    # if frame is read correctly ret is True
    out.write(frame)
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break
    
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    gray_show = cv2.resize(frame, (int(frame.shape[1]), int(frame.shape[0])), interpolation=cv2.INTER_CUBIC)
    #cv2.imshow('frame', gray_show)
    
    print("Writing frame {} / {}".format(frame_number, length))

    if cv2.waitKey(1) == ord('q'):
        break
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# Writing frame 1 / 4691
# Writing frame 2 / 4691
# Writing frame 3 / 4691
# Writing frame 4 / 4691
# Writing frame 5 / 4691
# Writing frame 6 / 4691
# Writing frame 7 / 4691
# Writing frame 8 / 4691
# Writing frame 9 / 4691
# Writing frame 10 / 4691
# Writing frame 11 / 4691
# Writing frame 12 / 4691
# Writing frame 13 / 4691
# Writing frame 14 / 4691
# Writing frame 15 / 4691
# Writing frame 16 / 4691
# Writing frame 17 / 4691
# Writing frame 18 / 4691
# Writing frame 19 / 4691
# Writing frame 20 / 4691
# Writing frame 21 / 4691
# Writing frame 22 / 4691
# Writing frame 23 / 4691
# Writing frame 24 / 4691
# Writing frame 25 / 4691
# Writing frame 26 / 4691
# Writing frame 27 / 4691
# Writing frame 28 / 4691
# Writing frame 29 / 4691
# Writing frame 30 / 4691
# Writing frame 31 / 4691
# Writing frame 32 / 4691
# Writing frame 33 / 4691
# Writing frame 34 / 4691
# Writing frame 35 / 4691
# Writing frame 36 / 4691
# Writing frame 37 / 4691
# Writing frame 38 / 4691
# ...

# %%
frame
